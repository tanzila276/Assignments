# %% [markdown]
# # Assignment:
# # Tanzila Ashraf(0172)
# Data Cleaning With Pandas:

# %% [markdown]
# Data cleaning is a crucial step in the data preparation process, often performed using Python's Pandas library. It involves identifying and correcting errors, inconsistencies, and missing values in your dataset to ensure its accuracy and reliability for analysis.
#
# The data cleaning process in Pandas is iterative, and you may need to repeat these steps multiple times to ensure the data is ready for analysis. Effective data cleaning is essential for accurate and meaningful insights in data analysis and machine learning tasks.

# %%
import pandas as pd
d=pd.read_csv("prog book.csv")
df=pd.DataFrame(d)
print(d)
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
# Display the first 10 rows of the dataset
df.head(10)
# Out:
#    Rating Reviews                                         Book_title  \
# 0    4.17   3,829                              The Elements of Style
# 1    4.01   1,406      The Information: A History, a Theory, a Flood
# 2    3.33       0       Responsive Web Design Overview For Beginners
# 3    3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4    4.06   1,325                                   How Google Works
# 5    3.84     117                                   The Meme Machine
# 6    4.09   5,938  Start with Why: How Great Leaders Inspire Ever...
# 7    4.15   1,817  Algorithms to Live By: The Computer Science of...
# 8    3.87   2,093  Weapons of Math Destruction: How Big Data Incr...
# 9    4.62       0  ZX Spectrum Games Code Club: Twenty fun games ...
#
#                                          Description  Number_Of_Pages  \
# 0  This style manual offers practical advice on i...              105
# ...

# %%
# Describe the dataset
df.describe()
# Out:
#            Rating  Number_Of_Pages       Price
# count  271.000000       271.000000  271.000000
# mean     4.067417       475.077491   54.541860
# std      0.290749       306.147492   35.711485
# min      3.000000        50.000000    9.323529
# 25%      3.915000       289.000000   30.751471
# 50%      4.100000       384.000000   46.317647
# 75%      4.250000       572.500000   67.854412
# max      5.000000      3168.000000  235.650000

# %%
#describe the dataset
df.tail()
# Out:
#      Rating Reviews                                         Book_title  \
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# 266  Dave Eberly's 3D Game Engine Design was the fi...              752
# 267  Continuing in the eighth edition, An Introduct...             1040
# 268  Knuth's classic work has been widely acclaimed...              896
# 269  "The bible of all fundamental algorithms and t...             3168
# 270  Designed to help individual programmers develo...              789
#
#                       Type       Price
# 266              Hardcover  203.108823
# ...

# %%
# Check for missing values
df.isna().sum()
# Out:
# Rating             0
# Reviews            0
# Book_title         0
# Description        0
# Number_Of_Pages    0
# Type               0
# Price              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Rating', 'Reviews', 'Book_title', 'Description', 'Number_Of_Pages',
#        'Type', 'Price'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Rating  Number_Of_Pages       Price
# count  271.000000       271.000000  271.000000
# mean     4.067417       475.077491   54.541860
# std      0.290749       306.147492   35.711485
# min      3.000000        50.000000    9.323529
# 25%      3.915000       289.000000   30.751471
# 50%      4.100000       384.000000   46.317647
# 75%      4.250000       572.500000   67.854412
# max      5.000000      3168.000000  235.650000

# %%
df.info
# Out:
# <bound method DataFrame.info of      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...

# %%
df.columns =df.columns.str.strip()

# %%
df.isnull().sum()
# Out:
# Rating             0
# Reviews            0
# Book_title         0
# Description        0
# Number_Of_Pages    0
# Type               0
# Price              0
# dtype: int64

# %%
df.shape
# Out:
# (271, 7)

# %%
df.dropna().shape
# Out:
# (271, 7)

# %%
df.dropna (how="all").shape
# Out:
# (271, 7)

# %%
df.drop_duplicates()
# Out:
#      Rating Reviews                                         Book_title  \
# 0      4.17   3,829                              The Elements of Style
# 1      4.01   1,406      The Information: A History, a Theory, a Flood
# 2      3.33       0       Responsive Web Design Overview For Beginners
# 3      3.97   1,658  Ghost in the Wires: My Adventures as the World...
# 4      4.06   1,325                                   How Google Works
# ..      ...     ...                                                ...
# 266    3.76       0  3D Game Engine Architecture: Engineering Real-...
# 267    3.94      22                An Introduction to Database Systems
# 268    4.49      36  The Art of Computer Programming, Volumes 1-3 B...
# 269    4.77       4  The Art of Computer Programming, Volumes 1-4a ...
# 270    3.84       5              A Discipline for Software Engineering
#
#                                            Description  Number_Of_Pages  \
# ...
